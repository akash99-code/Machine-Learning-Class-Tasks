# %% [markdown]
# ## ML Mini - Project

# %% [markdown]
# ##### Problem Statement:
# Predict Loan Eligibility for Dream Housing Finance company.
# Dream Housing Finance company deals in all kinds of home loans. They have presence across all urban, semi urban and rural areas. Customer first applies for home loan and after that company validates the customer eligibility for loan.
#
# Company wants to automate the loan eligibility process (real time) based on customer detail provided while filling online application form.
# These details are:
# - Gender,
# - Marital Status,
# - Education,
# - Number of Dependents,
# - Income,
# - Loan Amount,
# - Credit History
# - Self Employment
# - Loan Term
# - Property Area
#
# Use Machine Learning Technique to predcit `Loan Status`.

# %% [markdown]
# ##### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Loading Dataset

# %%
data = pd.read_csv('Loan_prediction_train.csv')
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# ##### Data expolaration

# %%
print("Shape of the Dataset: ",data.shape)
# Out:
# Shape of the Dataset:  (614, 13)

# %%
print("Dataset Information:")
data.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
print("Counts of categorical values:")
for col in ['Gender','Married','Dependents','Education','Self_Employed',"Property_Area","Credit_History"]:
    print(col)
    display(data[col].value_counts())
# Out:
# Counts of categorical values:
# Gender
# Male      489
# Female    112
# Name: Gender, dtype: int64
# Married
# Yes    398
# No     213
# Name: Married, dtype: int64
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64
# Education
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
# Self_Employed
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
# Credit_History
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
print("Missing values in dataset:")
data.isna().sum()
# Out:
# Missing values in dataset:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
print("No. of Unique values: ")
data.nunique()
# Out:
# No. of Unique values:
# Loan_ID              614
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
print("Values of Categorical Features:")
for col in data.iloc[:,2:]:
    if data[col].dtypes == 'O':
        print(">", col," :  ",data[col].unique())
# Out:
# Values of Categorical Features:
# > Married  :   ['No' 'Yes' nan]
# > Dependents  :   ['0' '1' '2' '3+' nan]
# > Education  :   ['Graduate' 'Not Graduate']
# > Self_Employed  :   ['No' 'Yes' nan]
# > Property_Area  :   ['Urban' 'Rural' 'Semiurban']
# > Loan_Status  :   ['Y' 'N']

# %% [markdown]
# **Inference:**
#    - Therefore, we need not use one hot encoding for any feature.

# %% [markdown]
# ## EDA

# %% [markdown]
# ###### Pandas Profiling

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(data, title="Pandas Profiling Report")

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# **Numerical Columns and Categorical columns**

# %%
numerical_cols  = [col for col in data.columns  if data[col].dtypes != 'O']
numerical_cols
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
categorical_cols  = [col for col in data.columns  if data[col].dtypes == 'O'  ]
categorical_cols.remove('Loan_ID')
categorical_cols
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %% [markdown]
# ###### Distribution of categorical features

# %%
temp = data.fillna("Missing")
plt.figure(figsize=(8,5))
n=data.shape[0]
for col in ["Credit_History", 'Loan_Amount_Term']+categorical_cols:
    ax=sns.countplot(x=col, data=temp, hue='Loan_Status')
    for p in ax.patches:
        ax.annotate('{:.0f}%'.format(p.get_height()/n *100), (p.get_x()+0.09, p.get_height()+2))
        ax.set(title="Countplot of "+col)
    plt.show()

# %% [markdown]
# **Inferences:**
# - Usually Loan approved for Credit_History 1.
# - Most of them apply Loan for 360 term period
# - Males are having higher loan approval rate.
# - Married person has higher loan approval rate.
# - Graduates has higher loan approval rate.
# - Being Self Employed or having dependents does not affect any loan approval rate.
# - Missing Data Points are not biased in Loan getting approved or not.
# - The Dataset is biased towards giving loan approval.

# %% [markdown]
# ##### Distribution of numerical features

# %%
for col in numerical_cols[:-2]:
    sns.histplot(x=col, data=data, hue='Loan_Status', kde=True, alpha=0.2).set(title='Density plot of '+col)
    plt.show()

# %% [markdown]
# **Inference:**
# - all of the numerical features are postively skewed
# - The dataset does not reveal in biases in approving Loan.

# %% [markdown]
# ##### Box plots

# %%
plt.figure(figsize=(8,7))

sns.boxplot(data=data, y="LoanAmount", x="Education").set(title="Loan Amount: Graduate vs Non-Graduates")
plt.show()

# %% [markdown]
# **Inference:**
# - Graduates applied Higher Loan Amount.
# - Non-Graduates have low range of loan amount being applied.

# %%
plt.figure(figsize=(8,7))

sns.boxplot(data=data, y="LoanAmount", x="Gender").set(title="Loan Amount: Male vs Feamle")
plt.show()

# %% [markdown]
# **Inference:**
# - Males has higher mean and range of loan amount being applied.

# %%
plt.figure(figsize=(8,7))

sns.boxplot(data=data, y="LoanAmount", x="Property_Area").set(title="Loan Amount: Urban vs Semi-urban vs rural")
plt.show()

# %% [markdown]
# **Inference:**
# - Rural People has higher mean Loan Amount applied comapred to Urban and Semiurban.

# %% [markdown]
# ### Correlations

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# **Interesting Correlations:**
# - `LoanAmount` and `ApplicantIncome` have higher correlation
# - `Credit_History` and `Loan_Status`  have higher correlation

# %%
## Pair plot of numerical columns
plt.figure(figsize=(20,20))
sns.pairplot(data=data, hue="Loan_Status")
plt.show()

# %% [markdown]
# **Note**
# - `Credit_History` is an important feature

# %%
## Pair plot of all columns
g = sns.PairGrid(df)
g.map_upper(sns.scatterplot )
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %% [markdown]
#                                                                           No Inference can be drawn, just Enjoy the picture.

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# ### Encoding Categorical columns

# %%
### Saving a copy in df
df = data.copy()

# %%
## Perfoeming Ordinal Encoding
enc = {
'Gender' : {'Female':0,'Male':1},
'Married' : {'No':0,'Yes':1},
'Education' : {'Not Graduate':0,'Graduate':1},
'Self_Employed' : {'No':0, 'Yes':1},
'Property_Area' : {'Urban':3,'Semiurban':2, 'Rural':1},
'Dependents' : {'0':0, '1':1,'2':2, '3+':3},
'Loan_Status': {'Y':1, 'N':0}
}
## encoding
for col in enc.keys():
    df[col] = df[col].map(enc[col])

# %%
### df - Encoded features but with missing values
df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002     1.0      0.0         0.0          1            0.0
# 1    LP001003     1.0      1.0         1.0          1            0.0
# 2    LP001005     1.0      1.0         0.0          1            1.0
# 3    LP001006     1.0      1.0         0.0          0            0.0
# 4    LP001008     1.0      0.0         0.0          1            0.0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978     0.0      0.0         0.0          1            0.0
# 610  LP002979     1.0      1.0         3.0          1            0.0
# 611  LP002983     1.0      1.0         1.0          1            0.0
# 612  LP002984     1.0      1.0         2.0          1            0.0
# 613  LP002990     0.0      0.0         0.0          1            1.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Property_Area  Loan_Status
# 0               1.0              3            1
# 1               1.0              1            0
# 2               1.0              3            1
# 3               1.0              3            1
# 4               1.0              3            1
# ..              ...            ...          ...
# 609             1.0              1            1
# 610             1.0              1            1
# 611             1.0              3            1
# 612             1.0              3            1
# 613             0.0              2            0
#
# [614 rows x 13 columns]

# %%
## Column s havinhg mising values
columns_noMissing = list(data.dropna(axis=1).columns)
columns_Missing = set(list(data.columns))-set(columns_noMissing)
columns_Missing
# Out:
# {'Credit_History',
#  'Dependents',
#  'Gender',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Married',
#  'Self_Employed'}

# %% [markdown]
# ### Imputing missing Values for numerical columns

# %%
### df2 - df+ numerical missing values filled
df2 = df.copy()

# %% [markdown]
# - Filling `Loan_Amount_Term` with Mode and rest with Mean

# %%
### Filling Loan Amount Term with Mode and rest with mean

numerical_missings={}
for col in numerical_cols:
    if df2[col].dtypes != 'O' and col !='Credit_History':
        if col == 'Loan_Amount_Term':
            numerical_missings[col] = df2[col].mode()[0]
            df2[col] = df2[col].fillna(numerical_missings[col])
        else:    
            numerical_missings[col] = df2[col].mean()
            df2[col] = df2[col].fillna(numerical_missings[col])
        
numerical_missings
# Out:
# {'ApplicantIncome': 5403.459283387622,
#  'CoapplicantIncome': 1621.245798027101,
#  'LoanAmount': 146.41216216216216,
#  'Loan_Amount_Term': 360.0}

# %%
df2.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ### Imputing missing values of categorical features

# %%
#### df3 - df2+ categorical missing values filled
df3 = df2.copy()

# %% [markdown]
# - Finding Votes for `Credit History` from other features.

# %%
## Finding Votes for `Credit History` from other features.
for col in categorical_cols:
    if col!='Credit_History':
        display(df2[[col, 'Credit_History']].groupby(col).median())
# Out:
#         Credit_History
# Gender
# 0.0                1.0
# 1.0                1.0
#          Credit_History
# Married
# 0.0                 1.0
# 1.0                 1.0
#             Credit_History
# Dependents
# 0.0                    1.0
# 1.0                    1.0
# 2.0                    1.0
# 3.0                    1.0
#            Credit_History
# Education
# 0                     1.0
# 1                     1.0
#                Credit_History
# Self_Employed
# 0.0                       1.0
# 1.0                       1.0
#                Credit_History
# Property_Area
# 1                         1.0
# 2                         1.0
# 3                         1.0
#              Credit_History
# Loan_Status
# 0                       1.0
# 1                       1.0

# %% [markdown]
# : Filling missing cells of `Credit History` with 1.0

# %%
## Filling missing cells of Credit History with 1.0
df3['Credit_History']=df3['Credit_History'].fillna(1.0)

# %% [markdown]
# - Finding Votes for `Self_Employed` from other features.

# %%
## Finding Votes for Self_Employed from other features.
for col in categorical_cols:
    if col!='Self_Employed':
        display(df2[[col, 'Self_Employed']].groupby(col).mean())
# Out:
#         Self_Employed
# Gender
# 0.0          0.144231
# 1.0          0.135484
#          Self_Employed
# Married
# 0.0           0.140704
# 1.0           0.142105
#             Self_Employed
# Dependents
# 0.0              0.113497
# 1.0              0.208333
# 2.0              0.166667
# 3.0              0.142857
#            Self_Employed
# Education
# 0               0.132812
# 1               0.143172
#                Self_Employed
# Property_Area
# 1                   0.153846
# 2                   0.143498
# 3                   0.126316
#              Self_Employed
# Loan_Status
# N                 0.142077
# Y                 0.140351

# %% [markdown]
# : Filling missing cells of `Self_Employed` with False

# %%
## Filling missing cells of `Self_Employed` with 0.0
df3['Self_Employed']=df3['Self_Employed'].fillna(0.0)

# %% [markdown]
# - Finding Votes for `Dependents` from other features.

# %%
## Finding Votes for `Dependents` from other features.
for col in categorical_cols:
    if col!='Dependents':
        display(df2[[col, 'Dependents']].groupby(col).mean())
# Out:
#         Dependents
# Gender
# 0.0       0.385321
# 1.0       0.840671
#          Dependents
# Married
# 0.0        0.287081
# 1.0        1.017949
#            Dependents
# Education
# 0            0.876923
# 1            0.731343
#                Dependents
# Self_Employed
# 0.0              0.743326
# 1.0              0.912500
#                Dependents
# Property_Area
# 1                0.751412
# 2                0.766520
# 3                0.769231
#              Dependents
# Loan_Status
# N              0.752688
# Y              0.767554

# %% [markdown]
# **Missing values of `Dependents` can be set as 1 when `Married` is True**

# %%
## Filling missing values of Married as True
df3['Married'].fillna(1, inplace=True)

# %%
## Missing values of Dependents can be set as 1 when Married is True
df3.loc[df3['Dependents'].isnull(),'Dependents'] = df3.loc[df3['Dependents'].isnull(),'Married']

# %% [markdown]
# * Filling Missing Values `Gender` randomly

# %%
df3['Gender'].fillna(np.random.randint(0,1), inplace=True)

# %%
df3.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df3
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002     1.0      0.0         0.0          1            0.0
# 1    LP001003     1.0      1.0         1.0          1            0.0
# 2    LP001005     1.0      1.0         0.0          1            1.0
# 3    LP001006     1.0      1.0         0.0          0            0.0
# 4    LP001008     1.0      0.0         0.0          1            0.0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978     0.0      0.0         0.0          1            0.0
# 610  LP002979     1.0      1.0         3.0          1            0.0
# 611  LP002983     1.0      1.0         1.0          1            0.0
# 612  LP002984     1.0      1.0         2.0          1            0.0
# 613  LP002990     0.0      0.0         0.0          1            1.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# 1               4583             1508.0  128.000000             360.0
# 2               3000                0.0   66.000000             360.0
# 3               2583             2358.0  120.000000             360.0
# 4               6000                0.0  141.000000             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0   71.000000             360.0
# 610             4106                0.0   40.000000             180.0
# 611             8072              240.0  253.000000             360.0
# 612             7583                0.0  187.000000             360.0
# 613             4583                0.0  133.000000             360.0
#
#      Credit_History  Property_Area  Loan_Status
# 0               1.0              3            1
# 1               1.0              1            0
# 2               1.0              3            1
# 3               1.0              3            1
# 4               1.0              3            1
# ..              ...            ...          ...
# 609             1.0              1            1
# 610             1.0              1            1
# 611             1.0              3            1
# 612             1.0              3            1
# 613             0.0              2            0
#
# [614 rows x 13 columns]

# %% [markdown]
# ## Modelling

# %%
## Libraries
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

# %%
model_summary =[]
columns=["Model", "Train_acc", "Train_F1", "Test_acc", "Test_F1"]

# %%
### Features and Target split
X=df3.drop(["Loan_Status", "Loan_ID"], axis=1)
y=df3.Loan_Status

# %% [markdown]
# ##### Scaling

# %%
### Scaling numerical columns
sc = StandardScaler()
sc.fit(X[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']])
X[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']] = sc.transform(X[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']])

# %% [markdown]
# ##### Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, stratify=y)

# %% [markdown]
# ## > Support Vector Machine - Model 1

# %%
temp = df3.dropna()
X=temp.iloc[:,2:-1]
y=temp.iloc[:,-1]
sc = StandardScaler()
sc.fit(X[numerical_cols])
X[numerical_cols] = sc.transform(X[numerical_cols])
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, stratify=y)

# %%
## Training
from sklearn import svm
clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
## Performance on Train set
print("Accuracy on train data :", clf.score(X_train, y_train)*100,"%")
print("Train data F1 Score :", f1_score(y_train, clf.predict(X_train), average='macro'))
# Out:
# Accuracy on train data : 80.65217391304348 %
# Train data F1 Score : 0.7263350690846864

# %%
## Prediction Permformance
preds = clf.predict(X_test)
score = clf.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("F1 Score :", f1_score(y_test, preds, average='macro'))
# Out:
# Accuracy on test data:  83.76623376623377 %
# F1 Score : 0.7712010459380757

# %%
## Applying SMOTE
# X_train, y_train = SMOTE().fit_resample(X_train, y_train)

# %% [markdown]
# **K-Fold CV**

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
scores = cross_val_score(svm.SVC(), X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print(clf)
print(scores)
print('Mean Accuracy: %.3f' % np.mean(scores))
print()
# Out:
# SVC()
# [0.80645161 0.83870968 0.82258065 0.80645161 0.83606557 0.75409836
#  0.7704918  0.81967213 0.7704918  0.78688525 0.79032258 0.80645161
#  0.82258065 0.79032258 0.83606557 0.81967213 0.83606557 0.83606557
#  0.75409836 0.7704918  0.82258065 0.83870968 0.79032258 0.79032258
#  0.80327869 0.7704918  0.81967213 0.80327869 0.80327869 0.81967213]
# Mean Accuracy: 0.805

# %% [markdown]
# **Hyperparameter Tuning**

# %%
param_grid = {'C': [0.1, 1, 10, 100],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'gamma':['scale', 'auto'],
              'kernel': ['linear', 'rbf', 'poly', 'sigmoid']}

grid = GridSearchCV(svm.SVC(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(X_train, y_train) 
 
# print best parameter after tuning 
print(grid.best_params_) 
grid_predictions = grid.predict(X_test) 

print("Accuracy on train data :", grid.score(X_train, y_train)*100,"%")
print("Train data F1 Score :", f1_score(y_train, grid.predict(X_train), average='macro'))
print()
preds = grid.predict(X_test)
score = grid.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("Test data F1 Score :", f1_score(y_test, grid.predict(X_test), average='macro'))
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# Accuracy on train data : 80.21739130434783 %
# Train data F1 Score : 0.718302276596747
#
# Accuracy on test data:  83.11688311688312 %
# Test data F1 Score : 0.7643596986817326

# %%
print(classification_report(y_test, preds)) 
print("Precision :", precision_score(y_test, preds, average='macro'))
print("Recall :", recall_score(y_test, preds, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.48      0.64        48
#            1       0.81      0.99      0.89       106
#
#     accuracy                           0.83       154
#    macro avg       0.88      0.73      0.76       154
# weighted avg       0.85      0.83      0.81       154
#
# Precision : 0.8830128205128205
# Recall : 0.7348663522012578

# %%
## Confusion Matrix
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, preds)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)
plt.show()

# %%
## storing best svm model
model_summary.append(["SVC", grid.score(X_train, y_train)*100,f1_score(y_train, grid.predict(X_train), average='macro'),score*100, f1_score(y_test, grid.predict(X_test), average='macro') ])
print(columns)
print(model_summary[0])
# Out:
# ['Model', 'Train_acc', 'Train_F1', 'Test_acc', 'Test_F1']
# ['SVC', 80.21739130434783, 0.718302276596747, 83.11688311688312, 0.7643596986817326]

# %% [markdown]
# ## > Naive Bayes - Model 2

# %%
temp = df.dropna()
X=temp.iloc[:,2:-1]
y=temp.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, stratify=y)

# %%
## Training
from sklearn.naive_bayes import GaussianNB
GNBclf = GaussianNB()
clf = GNBclf.fit(X_train, y_train)

# %%
## Performance on Train data
print("Accuracy on train data :", clf.score(X_train, y_train))
print("Train data F1 Score :", f1_score(y_train, clf.predict(X_train), average='macro'))
# Out:
# Accuracy on train data : 0.8055555555555556
# Train data F1 Score : 0.7426365456105232

# %%
## Prediction Permformance
preds = clf.predict(X_test)
score = clf.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("F1 Score :", f1_score(y_test, preds, average='macro'))
# Out:
# Accuracy on test data:  80.0 %
# F1 Score : 0.7333333333333334

# %% [markdown]
# **K-Fold CV**

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
scores = cross_val_score(clf, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print(clf)
print(scores)
print('Mean Accuracy: %.3f' % np.mean(scores))
print()
# Out:
# GaussianNB()
# [0.72916667 0.72916667 0.8125     0.8125     0.75       0.8125
#  0.83333333 0.85416667 0.8125     0.79166667 0.6875     0.8125
#  0.83333333 0.77083333 0.72916667 0.83333333 0.8125     0.77083333
#  0.875      0.8125     0.89583333 0.8125     0.72916667 0.79166667
#  0.72916667 0.8125     0.75       0.77083333 0.75       0.89583333]
# Mean Accuracy: 0.794

# %%
## Applying SMOTE
#X_train, y_train = SMOTE().fit_resample(X_train, y_train)

# %% [markdown]
# **Tuning**

# %%
param_grid = {
    'var_smoothing': np.logspace(0,-9, num=100)
}

grid = GridSearchCV(GaussianNB(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(X_train, y_train) 
 
# print best parameter after tuning 
print(grid.best_params_) 
grid_predictions = grid.predict(X_test) 

print("Accuracy on train data :", grid.score(X_train, y_train)*100,"%")
print("Train data F1 Score :", f1_score(y_train, grid.predict(X_train), average='macro'))
print()
preds = grid.predict(X_test)
score = grid.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("Test data F1 Score :", f1_score(y_test, grid.predict(X_test), average='macro'))
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# {'var_smoothing': 1.873817422860387e-09}
# Accuracy on train data : 80.27777777777779 %
# Train data F1 Score : 0.739902921512959
#
# Accuracy on test data:  80.0 %
# Test data F1 Score : 0.7333333333333334

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_test, preds)) 
print("Precision :", precision_score(y_test, preds, average='macro'))
print("Recall :", recall_score(y_test, preds, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.49      0.60        37
#            1       0.80      0.94      0.87        83
#
#     accuracy                           0.80       120
#    macro avg       0.79      0.71      0.73       120
# weighted avg       0.80      0.80      0.78       120
#
# Precision : 0.7933662034961901
# Recall : 0.7131227613155324

# %%
## Confusion Matrix
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, preds)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)
plt.show()

# %%
## storing best svm model
model_summary.append(["Naive_Bayes", grid.score(X_train, y_train)*100,f1_score(y_train, grid.predict(X_train), average='macro'),score*100, f1_score(y_test, grid.predict(X_test), average='macro') ])
print(columns)
print(model_summary[1])
# Out:
# ['Model', 'Train_acc', 'Train_F1', 'Test_acc', 'Test_F1']
# ['Naive_Bayes', 80.27777777777779, 0.739902921512959, 80.0, 0.7333333333333334]

# %% [markdown]
# ## Logistic Regression - Model 3

# %%
temp = df3.dropna()
X=temp.iloc[:,2:-1]
y=temp.iloc[:,-1]
sc = StandardScaler()
# sc.fit(X[numerical_cols])
# X[numerical_cols] = sc.transform(X[numerical_cols])
sc.fit(X[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']])
X[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']] = sc.transform(X[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']])
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, stratify=y)

# %%
## Training
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
## Performance on Training set
print("Accuracy on train data :", clf.score(X_train, y_train))
print("Train data F1 Score :", f1_score(y_train, clf.predict(X_train), average='macro'))
# Out:
# Accuracy on train data : 0.8043478260869565
# Train data F1 Score : 0.7223340040241449

# %%
## Prediction Performance
preds = clf.predict(X_test)
score = clf.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("F1 Score :", f1_score(y_test, preds, average='macro'))
# Out:
# Accuracy on test data:  83.76623376623377 %
# F1 Score : 0.7755756339259691

# %% [markdown]
# **K-Fold CV**

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
scores = cross_val_score(LogisticRegression(), X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print(clf)
print(scores)
print('Mean Accuracy: %.3f' % np.mean(scores))
print()
# Out:
# LogisticRegression()
# [0.79032258 0.83870968 0.85483871 0.80645161 0.83606557 0.75409836
#  0.78688525 0.83606557 0.80327869 0.78688525 0.79032258 0.80645161
#  0.83870968 0.79032258 0.83606557 0.81967213 0.81967213 0.85245902
#  0.75409836 0.78688525 0.82258065 0.82258065 0.80645161 0.80645161
#  0.80327869 0.75409836 0.81967213 0.81967213 0.80327869 0.81967213]
# Mean Accuracy: 0.809

# %%
## Applying SMOTE
#X_train, y_train = SMOTE().fit_resample(X_train, y_train)

# %% [markdown]
# **Hyperparameter Tuning**

# %%
param_grid = {
    'solver' : ['newton-cg', 'lbfgs', 'liblinear'],
'C' : [100, 10, 1.0, 0.1, 0.01]
}

grid = GridSearchCV(LogisticRegression(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(X_train, y_train) 
 
# print best parameter after tuning 
print(grid.best_params_) 
grid_predictions = grid.predict(X_test) 

print("Accuracy on train data :", grid.score(X_train, y_train)*100,"%")
print("Train data F1 Score :", f1_score(y_train, grid.predict(X_train), average='macro'))
print()
preds = grid.predict(X_test)
score = grid.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("Test data F1 Score :", f1_score(y_test, grid.predict(X_test), average='macro'))
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# {'C': 100, 'solver': 'newton-cg'}
# Accuracy on train data : 80.43478260869566 %
# Train data F1 Score : 0.7223340040241449
#
# Accuracy on test data:  83.76623376623377 %
# Test data F1 Score : 0.7755756339259691

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test, preds)) 
print("Precision :", precision_score(y_test, preds, average='macro'))
print("Recall :", recall_score(y_test, preds, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.50      0.66        48
#            1       0.81      0.99      0.89       106
#
#     accuracy                           0.84       154
#    macro avg       0.89      0.75      0.78       154
# weighted avg       0.86      0.84      0.82       154
#
# Precision : 0.8869767441860466
# Recall : 0.7452830188679245

# %%
## Confusion Matrix
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, preds)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)
plt.show()

# %%
## storing best svm model
model_summary.append(["LogisticRegression", grid.score(X_train, y_train)*100,f1_score(y_train, grid.predict(X_train), average='macro'),score*100, f1_score(y_test, grid.predict(X_test), average='macro') ])
print(columns)
print(model_summary[2])
# Out:
# ['Model', 'Train_acc', 'Train_F1', 'Test_acc', 'Test_F1']
# ['LogisticRegression', 80.43478260869566, 0.7223340040241449, 83.76623376623377, 0.7755756339259691]

# %% [markdown]
# ## KNN - Model 4

# %%
temp = df3.dropna()
X=temp.iloc[:,2:-1]
y=temp.iloc[:,-1]
sc = StandardScaler()
sc.fit(X[numerical_cols])
X[numerical_cols] = sc.transform(X[numerical_cols])
# sc.fit(X[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']])
# X[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']] = sc.transform(X[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']])
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, stratify=y)

# %%
## Training
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=10)
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
## Performance on TRaining set
print("Accuracy on train data :", clf.score(X_train, y_train))
print("Train data F1 Score :", f1_score(y_train, clf.predict(X_train), average='macro'))
# Out:
# Accuracy on train data : 0.8021739130434783
# Train data F1 Score : 0.7273301676014043

# %%
## Prediction
preds = clf.predict(X_test)
score = clf.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("Precision :", precision_score(y_test, preds, average='macro'))
print("Recall :", recall_score(y_test, preds, average='macro'))
print("F1 Score :", f1_score(y_test, preds, average='macro'))
# Out:
# Accuracy on test data:  84.4155844155844 %
# Precision : 0.8909254807692308
# Recall : 0.7556996855345912
# F1 Score : 0.7865557865557866

# %% [markdown]
# **K-Fold CV**

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
scores = cross_val_score(KNeighborsClassifier(n_neighbors=10), X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print(clf)
print(scores)
print('Mean Accuracy: %.3f' % np.mean(scores))
print()
# Out:
# KNeighborsClassifier(n_neighbors=10)
# [0.79032258 0.83870968 0.82258065 0.79032258 0.81967213 0.73770492
#  0.7704918  0.83606557 0.80327869 0.72131148 0.80645161 0.77419355
#  0.83870968 0.77419355 0.80327869 0.72131148 0.81967213 0.83606557
#  0.72131148 0.7704918  0.82258065 0.82258065 0.82258065 0.75806452
#  0.78688525 0.7704918  0.83606557 0.81967213 0.7704918  0.81967213]
# Mean Accuracy: 0.794

# %% [markdown]
# **Finding Best K neighbours**

# %%
## Finding Best K
x=[]
y=[]
for i in range(3,40):
    knn_temp = KNeighborsClassifier(n_neighbors=i)
    knn_temp.fit(X_train, y_train)
    preds = knn_temp.predict(X_test)
    score = knn_temp.score(X_test, y_test)
    x.append(i)
    y.append(score)


plt.figure(figsize=(8,5))
plt.plot(x,y)
plt.ylabel('Accuracy')
plt.xlabel('k value')
plt.title("Choosing K");
plt.show()
print("Best K - ", x[np.argmax(y)])
# Out:
# Best K -  10

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_test, preds)) 
print("Precision :", precision_score(y_test, preds, average='macro'))
print("Recall :", recall_score(y_test, preds, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.48      0.65        48
#            1       0.81      1.00      0.89       106
#
#     accuracy                           0.84       154
#    macro avg       0.90      0.74      0.77       154
# weighted avg       0.87      0.84      0.82       154
#
# Precision : 0.9045801526717557
# Recall : 0.7395833333333334

# %%
## Confusion Matrix
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, preds)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)
plt.show()

# %%
## storing best svm model
model_summary.append(["KNN", clf.score(X_train, y_train)*100,f1_score(y_train, clf.predict(X_train), average='macro'),score*100, f1_score(y_test, grid.predict(X_test), average='macro') ])
print(columns)
print(model_summary[3])
# Out:
# ['Model', 'Train_acc', 'Train_F1', 'Test_acc', 'Test_F1']
# ['KNN', 80.21739130434783, 0.7273301676014043, 83.76623376623377, 0.2376237623762376]

# %% [markdown]
# --------------------------------------------------

# %% [markdown]
# ## Decision Tree - Model 5

# %%
temp = df3.dropna()
X=temp.iloc[:,2:-1]
y=temp.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, stratify=y)

# %%
## Training
from sklearn import tree
clf = tree.DecisionTreeClassifier(min_samples_leaf=16)
clf = clf.fit(X_train, y_train)

# %%
## Performance on training set
print("Accuracy on train data :", clf.score(X_train, y_train))
print("Train data F1 Score :", f1_score(y_train, clf.predict(X_train), average='macro'))
# Out:
# Accuracy on train data : 0.8021739130434783
# Train data F1 Score : 0.7323101518784971

# %%
## Prediction Permformance
preds = clf.predict(X_test)
score = clf.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("F1 Score :", f1_score(y_test, preds, average='macro'))
# Out:
# Accuracy on test data:  82.46753246753246 %
# F1 Score : 0.7576216846400468

# %% [markdown]
# **K-Fold CV**

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
scores = cross_val_score(tree.DecisionTreeClassifier(min_samples_leaf=16), X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print(clf)
print(scores)
print('Mean Accuracy: %.3f' % np.mean(scores))
print()
# Out:
# DecisionTreeClassifier(min_samples_leaf=16)
# [0.79032258 0.82258065 0.83870968 0.75806452 0.7704918  0.73770492
#  0.75409836 0.83606557 0.80327869 0.73770492 0.75806452 0.80645161
#  0.82258065 0.77419355 0.81967213 0.78688525 0.81967213 0.75409836
#  0.70491803 0.75409836 0.80645161 0.82258065 0.74193548 0.79032258
#  0.7704918  0.72131148 0.80327869 0.80327869 0.80327869 0.78688525]
# Mean Accuracy: 0.783

# %% [markdown]
# **SMOTE**

# %%
## Applying SMOTE
X_train, y_train = SMOTE().fit_resample(X_train, y_train)

# %% [markdown]
# **Tuning**

# %%
param_grid = {'max_features': ['auto', 'sqrt', 'log2'],
              'ccp_alpha': [0.1, .01, .001],
              'max_depth' : [2,3,4,5,6, 8, 9,10,16,20,25,26,28,29,30,35],
              'criterion' :['gini', 'entropy'],
              'splitter': ['best', 'random'],
              
              
             }

grid = GridSearchCV( tree.DecisionTreeClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(X_train, y_train) 
 
# print best parameter after tuning 
print(grid.best_params_) 
grid_predictions = grid.predict(X_test) 

print("Accuracy on train data :", grid.score(X_train, y_train)*100,"%")
print("Train data F1 Score :", f1_score(y_train, grid.predict(X_train), average='macro'))
print()
preds = grid.predict(X_test)
score = grid.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("Test data F1 Score :", f1_score(y_test, grid.predict(X_test), average='macro'))
# Out:
# Fitting 5 folds for each of 576 candidates, totalling 2880 fits
# {'ccp_alpha': 0.01, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'splitter': 'random'}
# Accuracy on train data : 80.21739130434783 %
# Train data F1 Score : 0.718302276596747
#
# Accuracy on test data:  83.11688311688312 %
# Test data F1 Score : 0.7643596986817326
# C:\Users\Msc 2\anaconda3\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_test, preds)) 
print("Precision :", precision_score(y_test, preds, average='macro'))
print("Recall :", recall_score(y_test, preds, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.48      0.64        48
#            1       0.81      0.99      0.89       106
#
#     accuracy                           0.83       154
#    macro avg       0.88      0.73      0.76       154
# weighted avg       0.85      0.83      0.81       154
#
# Precision : 0.8830128205128205
# Recall : 0.7348663522012578

# %%
## Confusion Matrix
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, preds)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)
plt.show()

# %%
## storing best svm model
model_summary.append(["DecisionTree", grid.score(X_train, y_train)*100,f1_score(y_train, grid.predict(X_train), average='macro'),score*100, f1_score(y_test, grid.predict(X_test), average='macro') ])
print(columns)
print(model_summary[4])
# Out:
# ['Model', 'Train_acc', 'Train_F1', 'Test_acc', 'Test_F1']
# ['DecisionTree', 80.21739130434783, 0.718302276596747, 83.11688311688312, 0.7643596986817326]

# %% [markdown]
# **Visualing the Tree**

# %%
#!pip install dtreeviz

# %%
import graphviz

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=data.columns[2:-1],  
                     class_names=data.columns[-1],  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
from dtreeviz.trees import *

# %%
viz = dtreeviz(clf,
               X_train,
               y_train,
               target_name='Loan_Status')
              
viz.view()
# Out:
# C:\Users\Msc 2\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Random Forest - Model 6

# %%
temp = df3.dropna()
X=temp.iloc[:,2:-1]
y=temp.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, stratify=y)

# %%
## Training
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0, n_estimators=60)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=60, random_state=0)

# %%
## Training Performance
print("Accuracy on train data :", clf.score(X_train, y_train))
print("Train data F1 Score :", f1_score(y_train, clf.predict(X_train), average='macro'))
# Out:
# Accuracy on train data : 0.9978260869565218
# Train data F1 Score : 0.9974679503057726

# %%
## Prediction Performance
preds = clf.predict(X_test)
score = clf.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("F1 Score :", f1_score(y_test, preds, average='macro'))
# Out:
# Accuracy on test data:  79.22077922077922 %
# F1 Score : 0.7380952380952381

# %% [markdown]
# **SMOTE**

# %%
## Applying SMOTE
X_train, y_train = SMOTE().fit_resample(X_train, y_train)

# %% [markdown]
# **Tuning**

# %%
param_grid = {'max_features': ['auto', 'sqrt', 'log2'],
              'ccp_alpha': [0.1, .01, .001],
              'max_depth' : [4, 8, 9,10,20,22, 25,30],
              'criterion' :['gini', 'entropy'],
              'n_estimators':[30,50,55,58,60,62,63,65,70]
              
             }

grid = GridSearchCV( RandomForestClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(X_train, y_train) 
 
# print best parameter after tuning 
print(grid.best_params_) 
grid_predictions = grid.predict(X_test) 

print("Accuracy on train data :", grid.score(X_train, y_train)*100,"%")
print("Train data F1 Score :", f1_score(y_train, grid.predict(X_train), average='macro'))
print()
preds = grid.predict(X_test)
score = grid.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("Test data F1 Score :", f1_score(y_test, grid.predict(X_test), average='macro'))
# Out:
# Fitting 5 folds for each of 1296 candidates, totalling 6480 fits
# {'ccp_alpha': 0.01, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'n_estimators': 60}
# Accuracy on train data : 80.43478260869566 %
# Train data F1 Score : 0.7223340040241449
#
# Accuracy on test data:  83.11688311688312 %
# Test data F1 Score : 0.7643596986817326

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_test, preds)) 
print("Precision :", precision_score(y_test, preds, average='macro'))
print("Recall :", recall_score(y_test, preds, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.48      0.64        48
#            1       0.81      0.99      0.89       106
#
#     accuracy                           0.83       154
#    macro avg       0.88      0.73      0.76       154
# weighted avg       0.85      0.83      0.81       154
#
# Precision : 0.8830128205128205
# Recall : 0.7348663522012578

# %%
## Confusion Matrix
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, preds)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
plt.show()

# %%
## storing best svm model
model_summary.append(["RandomForest", grid.score(X_train, y_train)*100,f1_score(y_train, grid.predict(X_train), average='macro'),score*100, f1_score(y_test, grid.predict(X_test), average='macro') ])
print(columns)
print(model_summary[5])
# Out:
# ['Model', 'Train_acc', 'Train_F1', 'Test_acc', 'Test_F1']
# ['RandomForest', 80.43478260869566, 0.7223340040241449, 83.11688311688312, 0.7643596986817326]

# %% [markdown]
# ### AdaBoost -Model 7

# %%
temp = df3.dropna()
X=temp.iloc[:,2:-1]
y=temp.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, stratify=y)

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(n_estimators=30, random_state=0)
clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=30, random_state=0)

# %%
## Training Performance
print("Accuracy on train data :", clf.score(X_train, y_train))
print("Train data F1 Score :", f1_score(y_train, clf.predict(X_train), average='macro'))
# Out:
# Accuracy on train data : 0.8217391304347826
# Train data F1 Score : 0.7565760603009886

# %%
## Prediction Performance
preds = clf.predict(X_test)
score = clf.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("F1 Score :", f1_score(y_test, preds, average='macro'))
# Out:
# Accuracy on test data:  81.81818181818183 %
# F1 Score : 0.7596432552954293

# %%
param_grid = { 'base_estimator':[svm.SVC(),  GaussianNB(), LogisticRegression()],
              'n_estimators':[30,35,40,45,50,55,60], 
              'learning_rate':[1.0,0.5,0.1,0.2]
              
             }

grid = GridSearchCV( AdaBoostClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(X_train, y_train) 
 
# print best parameter after tuning 
print(grid.best_params_) 
grid_predictions = grid.predict(X_test) 

print("Accuracy on train data :", grid.score(X_train, y_train)*100,"%")
print("Train data F1 Score :", f1_score(y_train, grid.predict(X_train), average='macro'))
print()
preds = grid.predict(X_test)
score = grid.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("Test data F1 Score :", f1_score(y_test, grid.predict(X_test), average='macro'))
# Out:
# Fitting 5 folds for each of 84 candidates, totalling 420 fits
# {'base_estimator': GaussianNB(), 'learning_rate': 0.1, 'n_estimators': 30}
# Accuracy on train data : 80.21739130434783 %
# Train data F1 Score : 0.7201852953562524
#
# Accuracy on test data:  84.4155844155844 %
# Test data F1 Score : 0.7824858757062148
# C:\Users\Msc 2\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 140 fits failed out of a total of 420.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 140 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Msc 2\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Msc 2\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 506, in fit
#     return super().fit(X, y, sample_weight)
#   File "C:\Users\Msc 2\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 147, in fit
#     self._validate_estimator()
#   File "C:\Users\Msc 2\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 515, in _validate_estimator
#     raise TypeError(
# TypeError: AdaBoostClassifier with algorithm='SAMME.R' requires that the weak learner supports the calculation of class probabilities with a predict_proba method.
# Please change the base estimator or set algorithm='SAMME' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Msc 2\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.51086957 0.43695652
#  0.46086957 0.49782609 0.55434783 0.49347826 0.49565217 0.5673913
#  0.69782609 0.60652174 0.65       0.62391304 0.63913043 0.61086957
#  0.79782609 0.79782609 0.79782609 0.79782609 0.79347826 0.79565217
#  0.79347826 0.79130435 0.77173913 0.78043478 0.77173913 0.78695652
#  0.76956522 0.78478261 0.71521739 0.71521739 0.71521739 0.71086957
#  0.71304348 0.7173913  0.72173913 0.68695652 0.69782609 0.7
#  0.70434783 0.70869565 0.71086957 0.71086957 0.68695652 0.68695652
#  0.68695652 0.6826087  0.6826087  0.6826087  0.6826087  0.6826087
#  0.6826087  0.6826087  0.6826087  0.68478261 0.69782609 0.7       ]
#   warnings.warn(

# %%
print(classification_report(y_test, preds)) 
print("Precision :", precision_score(y_test, preds, average='macro'))
print("Recall :", recall_score(y_test, preds, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67        48
#            1       0.82      1.00      0.90       106
#
#     accuracy                           0.84       154
#    macro avg       0.91      0.75      0.78       154
# weighted avg       0.87      0.84      0.83       154
#
# Precision : 0.9076923076923077
# Recall : 0.75

# %%
## Confusion Matrix
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, preds)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)
plt.show()

# %%
## storing best svm model
model_summary.append(["AdaBoost", grid.score(X_train, y_train)*100,f1_score(y_train, grid.predict(X_train), average='macro'),score*100, f1_score(y_test, grid.predict(X_test), average='macro') ])
print(columns)
print(model_summary[6])
# Out:
# ['Model', 'Train_acc', 'Train_F1', 'Test_acc', 'Test_F1']
# ['AdaBoost', 80.21739130434783, 0.7201852953562524, 84.4155844155844, 0.7824858757062148]

# %% [markdown]
# ### XG Boost

# %%
temp = df3.dropna()
X=temp.iloc[:,2:-1]
y=temp.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, stratify=y)

# %%
## Training
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
clf = XGBClassifier(colsample_bytree=0.6267762776824761,gamma=1.0597824057699077,max_depth=10,min_child_weight=7.0,reg_alpha=96.0,reg_lambda=0.3742726525163004)
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1,
#               colsample_bytree=0.6267762776824761, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None,
#               gamma=1.0597824057699077, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=10, max_leaves=0,
#               min_child_weight=7.0, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, predictor='auto',
#               random_state=0, reg_alpha=96.0, reg_lambda=0.3742726525163004, ...)

# %%
## Training Performance
print("Accuracy on train data :", clf.score(X_train, y_train))
print("Train data F1 Score :", f1_score(y_train, clf.predict(X_train), average='macro'))
# Out:
# Accuracy on train data : 0.8021739130434783
# Train data F1 Score : 0.718302276596747

# %%
## Prediction Performance
preds = clf.predict(X_test)
score = clf.score(X_test, y_test)
print("Accuracy on test data: ", score*100,"%")
print("F1 Score :", f1_score(y_test, preds, average='macro'))
# Out:
# Accuracy on test data:  83.11688311688312 %
# F1 Score : 0.7643596986817326

# %%
#!pip install hyperopt

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from sklearn.metrics import accuracy_score

# %%
space={'max_depth': hp.quniform("max_depth", 3, 18, 1),
        'gamma': hp.uniform ('gamma', 1,9),
        'reg_alpha' : hp.quniform('reg_alpha', 40,180,1),
        'reg_lambda' : hp.uniform('reg_lambda', 0,1),
        'colsample_bytree' : hp.uniform('colsample_bytree', 0.5,1),
        'min_child_weight' : hp.quniform('min_child_weight', 0, 10, 1),
        'n_estimators': 180,
        'seed': 0
    }

# %%
def objective(space):
    clf=xgb.XGBClassifier(
                    n_estimators =space['n_estimators'], max_depth = int(space['max_depth']), gamma = space['gamma'],
                    reg_alpha = int(space['reg_alpha']),min_child_weight=int(space['min_child_weight']),
                    colsample_bytree=int(space['colsample_bytree']), early_stopping_rounds=10, eval_metric="auc")
    
    evaluation = [( X_train, y_train), ( X_test, y_test)]
    
    clf.fit(X_train, y_train,
            eval_set=evaluation,verbose=False)
    

    pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, pred>0.5)
    print ("SCORE:", accuracy)
    return {'loss': -accuracy, 'status': STATUS_OK }

# %%
import xgboost as xgb
trials = Trials()

best_hyperparams = fmin(fn = objective,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 100,
                        trials = trials)
# Out:
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.3116883116883117
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.6883116883116883
# SCORE:
# 0.8311688311688312
# SCORE:
# 0.3116883116883117
# 100%|██████████| 100/100 [00:04<00:00, 22.73trial/s, best loss: -0.8311688311688312]

# %%
print("The best hyperparameters are : ","\n")
print(best_hyperparams)
# Out:
# The best hyperparameters are :
#
# {'colsample_bytree': 0.662369707461159, 'gamma': 1.0712728745179732, 'max_depth': 12.0, 'min_child_weight': 4.0, 'reg_alpha': 94.0, 'reg_lambda': 0.6615879940997506}

# %%
print(classification_report(y_test, preds)) 
print("Precision :", precision_score(y_test, preds, average='macro'))
print("Recall :", recall_score(y_test, preds, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.48      0.64        48
#            1       0.81      0.99      0.89       106
#
#     accuracy                           0.83       154
#    macro avg       0.88      0.73      0.76       154
# weighted avg       0.85      0.83      0.81       154
#
# Precision : 0.8830128205128205
# Recall : 0.7348663522012578

# %%
## Confusion Matrix
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, preds)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
plt.show()

# %%
## storing best svm model
model_summary.append(["XGBoost", grid.score(X_train, y_train)*100,f1_score(y_train, grid.predict(X_train), average='macro'),score*100, f1_score(y_test, grid.predict(X_test), average='macro') ])
print(columns)
print(model_summary[7])
# Out:
# ['Model', 'Train_acc', 'Train_F1', 'Test_acc', 'Test_F1']
# ['XGBoost', 80.21739130434783, 0.7201852953562524, 83.11688311688312, 0.7824858757062148]

# %% [markdown]
# ### Model Summary

# %%
ms = pd.DataFrame(model_summary, columns=columns)
ms
# Out:
#                 Model  Train_acc  Train_F1   Test_acc   Test_F1
# 0                 SVC  80.217391  0.718302  83.116883  0.764360
# 1         Naive_Bayes  80.277778  0.739903  80.000000  0.733333
# 2  LogisticRegression  80.434783  0.722334  83.766234  0.775576
# 3                 KNN  80.217391  0.727330  83.766234  0.237624
# 4        DecisionTree  80.217391  0.718302  83.116883  0.764360
# 5        RandomForest  80.434783  0.722334  83.116883  0.764360
# 6            AdaBoost  80.217391  0.720185  84.415584  0.782486
# 7             XGBoost  80.217391  0.720185  83.116883  0.782486

# %%
ms[['Model', 'Train_acc', 'Test_acc']].plot(x='Model', kind='line', figsize=(15, 5))
# plt.xlabel('Longitude')
plt.ylabel('Accuracy')
plt.title('Accuracy of Various models')
plt.show()

# %%
ms[['Model', 'Train_F1', 'Test_F1']].plot(x='Model', kind='line', figsize=(15, 5))
# plt.xlabel('Longitude')
plt.ylabel('Accuracy')
plt.title('F1 Score of Various models')
plt.show()

# %% [markdown]
# ### Concluding Remarks

# %% [markdown]
# - None of the models could achieve accuracy of beyond 83% on an average, without overtfitting.
# - The Best Model Chosen is AdaBoost.
